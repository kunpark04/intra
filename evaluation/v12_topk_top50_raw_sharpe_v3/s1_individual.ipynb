# %% [markdown]
# # §1 Individual (unfiltered) (v12 top-50 raw-Sharpe, V3 filter)
#
# Per-combo metrics and per-combo equity/drawdown curves on the
# 20% OOS test partition with no ML#2 filter. Sizing: `fixed_dollars_500` (risk $500 per trade, flat).

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd

REPO = Path.cwd().resolve()
while not (REPO / 'src').exists() and REPO.parent != REPO:
    REPO = REPO.parent
sys.path.insert(0, str(REPO))

from scripts.evaluation._top_perf_common import (
    STARTING_EQUITY, POLICIES,
    apply_sizing, metrics_from_pnl, monte_carlo,
    load_setup,
    plot_indiv_equity, plot_indiv_dd,
    plot_combined_equity, plot_combined_dd,
    plot_ml2_indiv_equity, plot_ml2_indiv_dd,
    plot_ml2_combined_equity, plot_ml2_combined_dd,
    plot_mc_sims, plot_mc_pnl, plot_mc_sharpe, plot_mc_dd,
)

_ctx = load_setup(cost_per_contract_rt=0.0, top_strategies_path=REPO / 'evaluation' / 'top_strategies_v12_raw_sharpe_top50.json', version='v3')
bars            = _ctx['bars']
YEARS_SPAN      = _ctx['years_span']
strategies      = _ctx['strategies']
results_raw     = _ctx['results_raw']
combined_raw    = _ctx['combined_raw']
combos_ml2      = _ctx['combos_ml2']
s4_pnl_by_combo = _ctx['s4_pnl_by_combo']
ml2_portfolio   = _ctx['ml2_portfolio']
# Out:
# Top-K source: top_strategies_v12_raw_sharpe_top50.json
# Test partition: 514,563 bars  2024-10-22 05:08:00 -> 2026-04-08 20:20:00
# Years span: 1.461  (used to annualize Sharpe)
# Loaded 50 strategies.
# Running unfiltered composed_strategy_runner for each combo...
#   v11_7872...
#   v11_23634...
#   v11_15760...
#   v11_2646...
#   v11_7877...
#   v11_11149...
#   v11_14258...
#   v11_694...
#   v11_9978...
#   v11_8640...
#   v11_24300...
#   v11_17580...
#   v11_28169...
#   v11_13353...
#   v11_8982...
#   v11_18280...
#   v11_17684...
#   v11_3616...
#   v11_20470...
#   v11_25286...
#   v11_3350...
#   v11_13928...
#   v11_6587...
#   v11_10619...
#   v11_10676...
#   v11_7834...
#   v11_8638...
#   v11_263...
#   v11_4732...
#   v11_29033...
#   v11_20714...
#   v11_26614...
#   v11_11204...
#   v11_8592...
#   v11_872...
#   v11_22301...
#   v11_12101...
#   v11_28428...
#   v11_4991...
#   v11_14392...
#   v11_11082...
#   v11_27712...
#   v11_23889...
#   v11_16301...
#   v11_29351...
#   v11_11601...
#   v11_5022...
#   v11_17782...
#   v11_4057...
#   v11_10455...
# Wrote cache -> results_raw.pkl
# Combined unfiltered trades: 43,846
# Building V3-filtered trades per combo...
#   v11_7872...
#   Family A computed: prior_wr_10 mean=0.149, prior_wr_50 mean=0.155, has_history_50 rate=0.957
#   Family A computed: prior_wr_10 mean=0.149, prior_wr_50 mean=0.155, has_history_50 rate=0.957
#     n_trades=588  rr=4.56
#   v11_23634...
#   Family A computed: prior_wr_10 mean=0.126, prior_wr_50 mean=0.128, has_history_50 rate=0.984
#   Family A computed: prior_wr_10 mean=0.126, prior_wr_50 mean=0.128, has_history_50 rate=0.984
#     n_trades=1527  rr=3.94
#   v11_15760...
#   Family A computed: prior_wr_10 mean=0.171, prior_wr_50 mean=0.186, has_history_50 rate=0.878
#   Family A computed: prior_wr_10 mean=0.171, prior_wr_50 mean=0.186, has_history_50 rate=0.878
#     n_trades=205  rr=4.66
#   v11_2646...
#   Family A computed: prior_wr_10 mean=0.170, prior_wr_50 mean=0.179, has_history_50 rate=0.915
#   Family A computed: prior_wr_10 mean=0.170, prior_wr_50 mean=0.179, has_history_50 rate=0.915
#     n_trades=293  rr=2.63
#   v11_7877...
#   Family A computed: prior_wr_10 mean=0.358, prior_wr_50 mean=0.363, has_history_50 rate=0.967
#   Family A computed: prior_wr_10 mean=0.358, prior_wr_50 mean=0.363, has_history_50 rate=0.967
#     n_trades=755  rr=4.11
#   v11_11149...
#   Family A computed: prior_wr_10 mean=0.417, prior_wr_50 mean=0.438, has_history_50 rate=0.823
#   Family A computed: prior_wr_10 mean=0.417, prior_wr_50 mean=0.438, has_history_50 rate=0.823
#     n_trades=141  rr=1.15
#   v11_14258...
#   Family A computed: prior_wr_10 mean=0.199, prior_wr_50 mean=0.202, has_history_50 rate=0.909
#   Family A computed: prior_wr_10 mean=0.199, prior_wr_50 mean=0.202, has_history_50 rate=0.909
#     n_trades=276  rr=3.84
#   v11_694...
#   Family A computed: prior_wr_10 mean=0.485, prior_wr_50 mean=0.490, has_history_50 rate=0.897
#   Family A computed: prior_wr_10 mean=0.485, prior_wr_50 mean=0.490, has_history_50 rate=0.897
#     n_trades=242  rr=1.04
#   v11_9978...
#   Family A computed: prior_wr_10 mean=0.239, prior_wr_50 mean=0.249, has_history_50 rate=0.924
#   Family A computed: prior_wr_10 mean=0.239, prior_wr_50 mean=0.249, has_history_50 rate=0.924
#     n_trades=330  rr=2.79
#   v11_8640...
#   Family A computed: prior_wr_10 mean=0.205, prior_wr_50 mean=0.212, has_history_50 rate=0.956
#   Family A computed: prior_wr_10 mean=0.205, prior_wr_50 mean=0.212, has_history_50 rate=0.956
#     n_trades=569  rr=4.38
#   v11_24300...
#   Family A computed: prior_wr_10 mean=0.196, prior_wr_50 mean=0.208, has_history_50 rate=0.909
#   Family A computed: prior_wr_10 mean=0.196, prior_wr_50 mean=0.208, has_history_50 rate=0.909
#     n_trades=274  rr=4.82
#   v11_17580...
#   Family A computed: prior_wr_10 mean=0.407, prior_wr_50 mean=0.423, has_history_50 rate=0.934
#   Family A computed: prior_wr_10 mean=0.407, prior_wr_50 mean=0.423, has_history_50 rate=0.934
#     n_trades=378  rr=4.01
#   v11_28169...
#   Family A computed: prior_wr_10 mean=0.338, prior_wr_50 mean=0.353, has_history_50 rate=0.952
#   Family A computed: prior_wr_10 mean=0.338, prior_wr_50 mean=0.353, has_history_50 rate=0.952
#     n_trades=526  rr=3.83
#   v11_13353...
#   Family A computed: prior_wr_10 mean=0.162, prior_wr_50 mean=0.174, has_history_50 rate=0.939
#   Family A computed: prior_wr_10 mean=0.162, prior_wr_50 mean=0.174, has_history_50 rate=0.939
#     n_trades=412  rr=3.58
#   v11_8982...
#   Family A computed: prior_wr_10 mean=0.119, prior_wr_50 mean=0.122, has_history_50 rate=0.949
#   Family A computed: prior_wr_10 mean=0.119, prior_wr_50 mean=0.122, has_history_50 rate=0.949
#     n_trades=486  rr=4.03
#   v11_18280...
#   Family A computed: prior_wr_10 mean=0.177, prior_wr_50 mean=0.194, has_history_50 rate=0.908
#   Family A computed: prior_wr_10 mean=0.177, prior_wr_50 mean=0.194, has_history_50 rate=0.908
#     n_trades=272  rr=4.59
#   v11_17684...
#   Family A computed: prior_wr_10 mean=0.383, prior_wr_50 mean=0.386, has_history_50 rate=0.961
#   Family A computed: prior_wr_10 mean=0.383, prior_wr_50 mean=0.386, has_history_50 rate=0.961
#     n_trades=647  rr=4.70
#   v11_3616...
#   Family A computed: prior_wr_10 mean=0.364, prior_wr_50 mean=0.366, has_history_50 rate=0.973
#   Family A computed: prior_wr_10 mean=0.364, prior_wr_50 mean=0.366, has_history_50 rate=0.973
#     n_trades=911  rr=2.64
#   v11_20470...
#   Family A computed: prior_wr_10 mean=0.211, prior_wr_50 mean=0.212, has_history_50 rate=0.960
#   Family A computed: prior_wr_10 mean=0.211, prior_wr_50 mean=0.212, has_history_50 rate=0.960
#     n_trades=626  rr=3.87
#   v11_25286...
#   Family A computed: prior_wr_10 mean=0.290, prior_wr_50 mean=0.298, has_history_50 rate=0.916
#   Family A computed: prior_wr_10 mean=0.290, prior_wr_50 mean=0.298, has_history_50 rate=0.916
#     n_trades=298  rr=4.04
#   v11_3350...
#   Family A computed: prior_wr_10 mean=0.117, prior_wr_50 mean=0.128, has_history_50 rate=0.934
#   Family A computed: prior_wr_10 mean=0.117, prior_wr_50 mean=0.128, has_history_50 rate=0.934
#     n_trades=380  rr=4.92
#   v11_13928...
#   Family A computed: prior_wr_10 mean=0.192, prior_wr_50 mean=0.197, has_history_50 rate=0.941
#   Family A computed: prior_wr_10 mean=0.192, prior_wr_50 mean=0.197, has_history_50 rate=0.941
#     n_trades=424  rr=3.06
#   v11_6587...
#   Family A computed: prior_wr_10 mean=0.304, prior_wr_50 mean=0.322, has_history_50 rate=0.882
#   Family A computed: prior_wr_10 mean=0.304, prior_wr_50 mean=0.322, has_history_50 rate=0.882
#     n_trades=211  rr=3.74
#   v11_10619...
#   Family A computed: prior_wr_10 mean=0.395, prior_wr_50 mean=0.406, has_history_50 rate=0.917
#   Family A computed: prior_wr_10 mean=0.395, prior_wr_50 mean=0.406, has_history_50 rate=0.917
#     n_trades=300  rr=1.63
#   v11_10676...
#   Family A computed: prior_wr_10 mean=0.336, prior_wr_50 mean=0.369, has_history_50 rate=0.824
#   Family A computed: prior_wr_10 mean=0.336, prior_wr_50 mean=0.369, has_history_50 rate=0.824
#     n_trades=142  rr=2.55
#   v11_7834...
#   Family A computed: prior_wr_10 mean=0.375, prior_wr_50 mean=0.385, has_history_50 rate=0.917
#   Family A computed: prior_wr_10 mean=0.375, prior_wr_50 mean=0.385, has_history_50 rate=0.917
#     n_trades=303  rr=3.14
#   v11_8638...
#   Family A computed: prior_wr_10 mean=0.227, prior_wr_50 mean=0.266, has_history_50 rate=0.866
#   Family A computed: prior_wr_10 mean=0.227, prior_wr_50 mean=0.266, has_history_50 rate=0.866
#     n_trades=186  rr=4.73
#   v11_263...
#   Family A computed: prior_wr_10 mean=0.345, prior_wr_50 mean=0.348, has_history_50 rate=0.948
#   Family A computed: prior_wr_10 mean=0.345, prior_wr_50 mean=0.348, has_history_50 rate=0.948
#     n_trades=480  rr=1.70
#   v11_4732...
#   Family A computed: prior_wr_10 mean=0.149, prior_wr_50 mean=0.173, has_history_50 rate=0.841
#   Family A computed: prior_wr_10 mean=0.149, prior_wr_50 mean=0.173, has_history_50 rate=0.841
#     n_trades=157  rr=4.63
#   v11_29033...
#   Family A computed: prior_wr_10 mean=0.440, prior_wr_50 mean=0.456, has_history_50 rate=0.852
#   Family A computed: prior_wr_10 mean=0.440, prior_wr_50 mean=0.456, has_history_50 rate=0.852
#     n_trades=169  rr=2.65
#   v11_20714...
#   Family A computed: prior_wr_10 mean=0.138, prior_wr_50 mean=0.143, has_history_50 rate=0.967
#   Family A computed: prior_wr_10 mean=0.138, prior_wr_50 mean=0.143, has_history_50 rate=0.967
#     n_trades=759  rr=3.69
#   v11_26614...
#   Family A computed: prior_wr_10 mean=0.347, prior_wr_50 mean=0.356, has_history_50 rate=0.959
#   Family A computed: prior_wr_10 mean=0.347, prior_wr_50 mean=0.356, has_history_50 rate=0.959
#     n_trades=607  rr=3.80
#   v11_11204...
#   Family A computed: prior_wr_10 mean=0.434, prior_wr_50 mean=0.450, has_history_50 rate=0.775
#   Family A computed: prior_wr_10 mean=0.434, prior_wr_50 mean=0.450, has_history_50 rate=0.775
#     n_trades=111  rr=3.97
#   v11_8592...
#   Family A computed: prior_wr_10 mean=0.129, prior_wr_50 mean=0.134, has_history_50 rate=0.963
#   Family A computed: prior_wr_10 mean=0.129, prior_wr_50 mean=0.134, has_history_50 rate=0.963
#     n_trades=679  rr=4.22
#   v11_872...
#   Family A computed: prior_wr_10 mean=0.246, prior_wr_50 mean=0.245, has_history_50 rate=0.930
#   Family A computed: prior_wr_10 mean=0.246, prior_wr_50 mean=0.245, has_history_50 rate=0.930
#     n_trades=357  rr=3.73
#   v11_22301...
#   Family A computed: prior_wr_10 mean=0.291, prior_wr_50 mean=0.294, has_history_50 rate=0.983
#   Family A computed: prior_wr_10 mean=0.291, prior_wr_50 mean=0.294, has_history_50 rate=0.983
#     n_trades=1478  rr=1.91
#   v11_12101...
#   Family A computed: prior_wr_10 mean=0.205, prior_wr_50 mean=0.211, has_history_50 rate=0.922
#   Family A computed: prior_wr_10 mean=0.205, prior_wr_50 mean=0.211, has_history_50 rate=0.922
#     n_trades=322  rr=3.85
#   v11_28428...
#   Family A computed: prior_wr_10 mean=0.145, prior_wr_50 mean=0.148, has_history_50 rate=0.971
#   Family A computed: prior_wr_10 mean=0.145, prior_wr_50 mean=0.148, has_history_50 rate=0.971
#     n_trades=875  rr=3.35
#   v11_4991...
#   Family A computed: prior_wr_10 mean=0.414, prior_wr_50 mean=0.421, has_history_50 rate=0.912
#   Family A computed: prior_wr_10 mean=0.414, prior_wr_50 mean=0.421, has_history_50 rate=0.912
#     n_trades=283  rr=1.72
#   v11_14392...
#   Family A computed: prior_wr_10 mean=0.417, prior_wr_50 mean=0.439, has_history_50 rate=0.819
#   Family A computed: prior_wr_10 mean=0.417, prior_wr_50 mean=0.439, has_history_50 rate=0.819
#     n_trades=138  rr=2.99
#   v11_11082...
#   Family A computed: prior_wr_10 mean=0.245, prior_wr_50 mean=0.266, has_history_50 rate=0.890
#   Family A computed: prior_wr_10 mean=0.245, prior_wr_50 mean=0.266, has_history_50 rate=0.890
#     n_trades=227  rr=3.55
#   v11_27712...
#   Family A computed: prior_wr_10 mean=0.214, prior_wr_50 mean=0.233, has_history_50 rate=0.897
#   Family A computed: prior_wr_10 mean=0.214, prior_wr_50 mean=0.233, has_history_50 rate=0.897
#     n_trades=243  rr=3.40
#   v11_23889...
#   Family A computed: prior_wr_10 mean=0.365, prior_wr_50 mean=0.377, has_history_50 rate=0.938
#   Family A computed: prior_wr_10 mean=0.365, prior_wr_50 mean=0.377, has_history_50 rate=0.938
#     n_trades=403  rr=4.10
#   v11_16301...
#   Family A computed: prior_wr_10 mean=0.345, prior_wr_50 mean=0.357, has_history_50 rate=0.900
#   Family A computed: prior_wr_10 mean=0.345, prior_wr_50 mean=0.357, has_history_50 rate=0.900
#     n_trades=250  rr=2.98
#   v11_29351...
#   Family A computed: prior_wr_10 mean=0.399, prior_wr_50 mean=0.404, has_history_50 rate=0.958
#   Family A computed: prior_wr_10 mean=0.399, prior_wr_50 mean=0.404, has_history_50 rate=0.958
#     n_trades=600  rr=4.00
#   v11_11601...
#   Family A computed: prior_wr_10 mean=0.362, prior_wr_50 mean=0.365, has_history_50 rate=0.978
#   Family A computed: prior_wr_10 mean=0.362, prior_wr_50 mean=0.365, has_history_50 rate=0.978
#     n_trades=1118  rr=1.60
#   v11_5022...
#   Family A computed: prior_wr_10 mean=0.220, prior_wr_50 mean=0.234, has_history_50 rate=0.887
#   Family A computed: prior_wr_10 mean=0.220, prior_wr_50 mean=0.234, has_history_50 rate=0.887
#     n_trades=221  rr=4.81
#   v11_17782...
#   Family A computed: prior_wr_10 mean=0.317, prior_wr_50 mean=0.319, has_history_50 rate=0.938
#   Family A computed: prior_wr_10 mean=0.317, prior_wr_50 mean=0.319, has_history_50 rate=0.938
#     n_trades=402  rr=2.39
#   v11_4057...
#   Family A computed: prior_wr_10 mean=0.146, prior_wr_50 mean=0.172, has_history_50 rate=0.883
#   Family A computed: prior_wr_10 mean=0.146, prior_wr_50 mean=0.172, has_history_50 rate=0.883
#     n_trades=213  rr=4.61
#   v11_10455...
#   Family A computed: prior_wr_10 mean=0.284, prior_wr_50 mean=0.287, has_history_50 rate=0.981
#   Family A computed: prior_wr_10 mean=0.284, prior_wr_50 mean=0.287, has_history_50 rate=0.981
#     n_trades=1302  rr=3.32
# Wrote cache -> _ml2_cache.pkl
# ML2 portfolio trade counts: {'fixed_dollars_500': 3223}

# %%
rows = []
for r in results_raw:
    if r['trades'].empty:
        for policy in POLICIES:
            rows.append({'combo_id': r['combo_id'], 'policy': policy,
                         **metrics_from_pnl(np.array([]), YEARS_SPAN, policy=policy)})
        continue
    t = r['trades'].sort_values('date', kind='mergesort')
    pnl_base = t['actual_pnl'].to_numpy(dtype=float)
    risk_base = t['dollar_risk'].to_numpy(dtype=float)
    r_mult = np.where(risk_base > 0, pnl_base / risk_base, 0.0)
    for policy in POLICIES:
        pnl = apply_sizing(pnl_base, risk_base, policy)
        rows.append({'combo_id': r['combo_id'], 'policy': policy,
                     **metrics_from_pnl(pnl, YEARS_SPAN, policy=policy, r=r_mult)})
perf1 = pd.DataFrame(rows)
perf1
# Out:
#      combo_id             policy  n_trades  trades_per_year  win_rate  \
# 0    v11_7872  fixed_dollars_500       889            608.5    0.1350
# 1   v11_23634  fixed_dollars_500      2394           1638.6    0.1316
# 2   v11_15760  fixed_dollars_500       350            239.6    0.2057
# 3    v11_2646  fixed_dollars_500       294            201.2    0.1667
# 4    v11_7877  fixed_dollars_500      1595           1091.7    0.3774
# 5   v11_11149  fixed_dollars_500       286            195.8    0.4580
# 6   v11_14258  fixed_dollars_500       541            370.3    0.2366
# 7     v11_694  fixed_dollars_500       242            165.6    0.4835
# 8    v11_9978  fixed_dollars_500       446            305.3    0.2130
# 9    v11_8640  fixed_dollars_500       969            663.2    0.1940
# 10  v11_24300  fixed_dollars_500       344            235.5    0.1948
# 11  v11_17580  fixed_dollars_500      1073            734.4    0.4007
# 12  v11_28169  fixed_dollars_500      1882           1288.2    0.3714
# 13  v11_13353  fixed_dollars_500       549            375.8    0.1457
# 14   v11_8982  fixed_dollars_500      1093            748.1    0.1290
# 15  v11_18280  fixed_dollars_500       830            568.1    0.1819
# 16  v11_17684  fixed_dollars_500      1406            962.3    0.4061
# 17   v11_3616  fixed_dollars_500      1868           1278.6    0.3769
# 18  v11_20470  fixed_dollars_500       884            605.1    0.2251
# 19  v11_25286  fixed_dollars_500       807            552.4    0.3432
# 20   v11_3350  fixed_dollars_500       705            482.5    0.1050
# 21  v11_13928  fixed_dollars_500       425            290.9    0.1976
# 22   v11_6587  fixed_dollars_500       213            145.8    0.3052
# 23  v11_10619  fixed_dollars_500       445            304.6    0.4247
# 24  v11_10676  fixed_dollars_500       532            364.1    0.3308
# 25   v11_7834  fixed_dollars_500       766            524.3    0.3616
# 26   v11_8638  fixed_dollars_500       316            216.3    0.2057
# 27    v11_263  fixed_dollars_500       482            329.9    0.3444
# 28   v11_4732  fixed_dollars_500       157            107.5    0.1465
# 29  v11_29033  fixed_dollars_500       751            514.0    0.4634
# 30  v11_20714  fixed_dollars_500      1307            894.6    0.1400
# 31  v11_26614  fixed_dollars_500      1934           1323.7    0.3573
# 32  v11_11204  fixed_dollars_500       184            125.9    0.3804
# 33   v11_8592  fixed_dollars_500       844            577.7    0.1232
# 34    v11_872  fixed_dollars_500       466            319.0    0.2403
# 35  v11_22301  fixed_dollars_500      2862           1958.9    0.3148
# 36  v11_12101  fixed_dollars_500       323            221.1    0.2012
# 37  v11_28428  fixed_dollars_500      1311            897.3    0.1472
# 38   v11_4991  fixed_dollars_500       875            598.9    0.4103
# 39  v11_14392  fixed_dollars_500       863            590.7    0.4125
# 40  v11_11082  fixed_dollars_500       645            441.5    0.2760
# 41  v11_27712  fixed_dollars_500       325            222.4    0.2092
# 42  v11_23889  fixed_dollars_500       404            276.5    0.3639
# 43  v11_16301  fixed_dollars_500       437            299.1    0.3181
# 44  v11_29351  fixed_dollars_500      1863           1275.1    0.4208
# 45  v11_11601  fixed_dollars_500      2068           1415.5    0.3477
# 46   v11_5022  fixed_dollars_500       621            425.0    0.3124
# 47  v11_17782  fixed_dollars_500       401            274.5    0.3167
# 48   v11_4057  fixed_dollars_500       214            146.5    0.1355
# 49  v11_10455  fixed_dollars_500      2365           1618.7    0.2786
#
#     total_pnl_dollars  total_return_pct  sharpe_ratio  max_drawdown_pct  \
# 0            45433.51             90.87        1.9295             15.50
# 1            34592.29             69.18        0.9210             29.07
# 2            14476.40             28.95        0.8383             13.44
# 3           -13728.96            -27.46       -1.2725             37.27
# 4            31254.03             62.51        1.2467             17.49
# 5            -5947.54            -11.90       -0.7448             16.47
# 6            35924.70             71.85        1.3074             15.56
# 7            -1485.81             -2.97       -0.1986             12.69
# 8            23577.99             47.16        1.6803              8.63
# 9            16553.70             33.11        0.5295             24.66
# 10           16927.98             33.86        0.8897             18.26
# 11           10917.57             21.84        0.5613             22.17
# 12           -3319.62             -6.64       -0.1068             29.34
# 13            8864.85             17.73        0.4581             25.49
# 14            6147.16             12.29        0.2047             31.98
# 15           24100.57             48.20        0.9941             18.71
# 16           51610.85            103.22        2.1731             12.64
# 17           20276.94             40.55        0.8083             20.47
# 18           28981.53             57.96        1.1571             21.85
# 19           -3347.73             -6.70       -0.2133             32.15
# 20            9497.84             19.00        0.4994             26.51
# 21           26769.20             53.54        1.5272             16.48
# 22             356.32              0.71        0.0286             14.90
# 23            5392.77             10.79        0.5472             12.77
# 24           11071.47             22.14        0.6320             12.87
# 25           21491.55             42.98        0.8656             24.72
# 26          -12746.39            -25.49       -0.9036             42.45
# 27          -15576.70            -31.15       -0.9964             41.49
# 28           -6534.25            -13.07       -0.7634             25.98
# 29           14051.09             28.10        1.1135             16.02
# 30           20091.82             40.18        0.6193             24.07
# 31           23129.18             46.26        0.6275             24.71
# 32           -1233.19             -2.47       -0.1587             11.85
# 33            1365.05              2.73        0.0683             28.92
# 34           21862.35             43.72        1.1880             17.19
# 35           12547.65             25.10        0.3492             37.99
# 36           -3937.86             -7.88       -0.2685             24.68
# 37            -355.17             -0.71       -0.0142             38.66
# 38           15214.67             30.43        0.8786             19.61
# 39           19844.99             39.69        1.2153             10.20
# 40            5602.66             11.21        0.2351             30.45
# 41           -8843.23            -17.69       -0.6639             32.55
# 42           19288.15             38.58        1.1595             13.00
# 43           -2360.65             -4.72       -0.1315             23.28
# 44           -1222.16             -2.44       -0.0640             31.09
# 45           47307.13             94.61        1.5677             17.56
# 46          -24733.00            -49.47       -1.5558             63.73
# 47           13377.70             26.76        0.7877             16.65
# 48           13421.68             26.84        0.9144             14.73
# 49           36313.03             72.63        0.7736             34.70
#
#     max_drawdown_dollars
# 0               17298.91
# 1               30790.78
# 2               10010.94
# 3               19084.91
# 4               13771.60
# 5                8628.82
# 6               14114.52
# 7                6946.86
# 8                5288.40
# 9               21118.00
# 10              13455.53
# 11              15959.62
# 12              18199.40
# 13              19788.69
# 14              26391.89
# 15              13040.10
# 16              10385.87
# 17              17463.69
# 18              18967.27
# 19              17369.93
# 20              19249.21
# 21              13368.70
# 22               8514.39
# 23               7107.11
# 24               8681.78
# 25              16867.74
# 26              27478.67
# 27              22657.72
# 28              14550.12
# 29              12139.53
# 30              21581.33
# 31              18906.73
# 32               6284.35
# 33              19426.71
# 34               8595.64
# 35              35578.77
# 36              14745.82
# 37              30545.98
# 38              13013.32
# 39               6477.26
# 40              21170.85
# 41              19270.57
# 42              10027.80
# 43              12529.87
# 44              16760.80
# 45              18713.20
# 46              32319.93
# 47              11583.26
# 48              10751.02
# 49              43876.31

# %%
plot_indiv_equity(results_raw, 'fixed_dollars_500')

# %%
plot_indiv_dd(results_raw, 'fixed_dollars_500')
